# %%
from simglucose.simulation.user_interface import simulate
simulate()
# Out:
# Show animation? (y/n) y
# Use multiple processes? (y/n) y
# Folder name to save results [default]:
# Results will be saved in /home/hero/Downloads/Uniandes/tesis/results/2020-01-29_11-32-29
# Input simulation time (hr): 1
# Select scnenario:
# [1] Random Scnenario
# [2] Custom Scnenario
# >>>1
# Select random seed for random scenario [None]:
# Input simulation start time (hr): 8
# Simulation start time is set to 2020-01-29 08:00:00.
# Select virtual patients:
# [1] All
# [2] All Adolescents
# [3] All Adults
# [4] All Children
# [5] By ID
# >>> 3
# Select the CGM sensor:
# [1] Dexcom
# [2] GuardianRT
# [3] Navigator
# >>> 1
# Select Random Seed for Sensor Noise [None]:
# Select the insulin pump:
# [1] Cozmo
# [2] Insulet
# >>> 1
# Select controller:
# [1] Basal-Bolus Controller
# >>>1
# Simulation took 9.719400882720947 sec.
# 0
